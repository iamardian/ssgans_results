# %% [markdown]
# <a href="https://colab.research.google.com/github/iamardian/ssgans_results/blob/main/ec-gan_digikalamag_p-10_w-20_t-50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install transformers==4.3.2
# !rm -r ./semi_supervised_learning_with_gan ;git clone https://github.com/iamardian/semi_supervised_learning_with_gan.git
# !python ./semi_supervised_learning_with_gan/ssgan_parsbert.py -d digikalamag -p 0.01
# !python ./semi_supervised_learning_with_gan/ecgan_parsbert.py -d digikalamag -p 0.1 -w 0.2 -t 0.5 -e 100
# Out:
# Streaming output truncated to the last 5000 lines.
# call create_path_if_not_exists
# dir_path : /content/drive/MyDrive/NLP/save/ec_gan|digikalamag|0.1|0.2|0.5/best
# call create_path_if_not_exists
# dir_path : /content/drive/MyDrive/NLP/save/ec_gan|digikalamag|0.1|0.2|0.5
# best_model_accuracy : 91.39504563233378
# call save_params
# call create_path_if_not_exists
# dir_path : /content/drive/MyDrive/NLP/save/ec_gan|digikalamag|0.1|0.2|0.5
# ['/content/drive/MyDrive/NLP/save/ec_gan|digikalamag|0.1|0.2|0.5/073_digikalamag_0.1_0.2_0.5.pth', '/content/drive/MyDrive/NLP/save/ec_gan|digikalamag|0.1|0.2|0.5/074_digikalamag_0.1_0.2_0.5.pth', '/content/drive/MyDrive/NLP/save/ec_gan|digikalamag|0.1|0.2|0.5/best_model.pth']
#
# ======== Epoch 76 / 100 ========
# Training...
# ./semi_supervised_learning_with_gan/ecgan_parsbert.py:374: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = self.softmax(logits)
# ...
