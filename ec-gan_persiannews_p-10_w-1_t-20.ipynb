# %% [markdown]
# <a href="https://colab.research.google.com/github/iamardian/ssgans_results/blob/main/ec-gan_persiannews_p-10_w-1_t-20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install transformers==4.3.2
# !rm -r ./semi_supervised_learning_with_gan ;git clone https://github.com/iamardian/semi_supervised_learning_with_gan.git
# !python ./semi_supervised_learning_with_gan/ssgan_parsbert.py -d digikalamag -p 0.01
# !python ./semi_supervised_learning_with_gan/ecgan_parsbert.py -d persiannews -p 0.1 -w 0.01 -t 0.2 -e 100
# Out:
# Streaming output truncated to the last 5000 lines.
# evaluation
#     epoch        acc
# 0       1  53.343351
# 1       2  82.043576
# 2       3  95.942900
# 3       4  96.093163
# 4       5  88.880541
# 5       6  95.567243
# 6       7  78.061608
# 7       8  98.196844
# 8       9  97.520661
# 9      10  97.370398
# 10     11  98.422239
# 11     12  98.497370
# 12     13  98.647633
# 13     14  76.709241
# 14     15  67.392938
# 15     16  89.481593
# 16     17  97.220135
# 17     18  97.220135
# 18     19  93.613824
# 19     20  95.717506
# 20     21  96.093163
# 21     22  96.543952
# 22     23  80.841473
# 23     24  91.284748
# 24     25  91.359880
# 25     26  76.483847
# 26     27  67.693464
# 27     28  76.934636
# 28     29  91.885800
# 29     30  93.914350
# 30     31  95.642374
# 31     32  90.833959
# 32     33  84.973704
# 33     34  93.989482
# 34     35  87.528174
# 35     36  84.673178
# 36     37  80.691210
# 37     38  85.048835
# 38     39  85.499624
# ...
