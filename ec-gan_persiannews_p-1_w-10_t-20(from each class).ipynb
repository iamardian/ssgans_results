# %% [markdown]
# <a href="https://colab.research.google.com/github/iamardian/ssgans_results/blob/main/ec-gan_persiannews_p-1_w-10_t-20(from%20each%20class).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers==4.3.2
# !rm -r ./semi_supervised_learning_with_gan ;git clone https://github.com/iamardian/semi_supervised_learning_with_gan.git
# !python ./semi_supervised_learning_with_gan/ssgan_parsbert.py -d digikalamag -p 0.01
# !python ./semi_supervised_learning_with_gan/ecgan_parsbert.py -d persiannews -p 0.01 -w 0.1 -t 0.2 -e 100
# Out:
# Streaming output truncated to the last 5000 lines.
# 10     11  75.337838
# 11     12  83.175676
# 12     13  86.959459
# 13     14  90.067568
# 14     15  93.040541
# 15     16  90.067568
# 16     17  90.202703
# 17     18  90.405405
# 18     19  90.743243
# 19     20  88.716216
# 20     21  88.648649
# 21     22  88.648649
# 22     23  91.486486
# 23     24  91.959459
# 24     25  92.094595
# 25     26  91.351351
# 26     27  91.418919
# 27     28  91.756757
# 28     29  91.756757
# 29     30  92.162162
# 30     31  92.364865
# 31     32  92.297297
# 32     33  92.567568
# 33     34  92.364865
# 34     35  92.432432
# 35     36  92.432432
# 36     37  92.635135
# 37     38  92.770270
# 38     39  92.837838
# 39     40  92.635135
# 40     41  92.635135
# 41     42  92.500000
# 42     43  92.364865
# 43     44  92.094595
# 44     45  92.500000
# 45     46  92.297297
# 46     47  92.364865
# 47     48  92.297297
# 48     49  92.702703
# 49     50  92.702703
# 50     51  92.905405
# ...
