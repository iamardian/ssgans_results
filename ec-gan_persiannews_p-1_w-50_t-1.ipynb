# %% [markdown]
# <a href="https://colab.research.google.com/github/iamardian/ssgans_results/blob/main/ec-gan_persiannews_p-1_w-50_t-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install transformers==4.3.2
# !rm -r ./semi_supervised_learning_with_gan ;git clone https://github.com/iamardian/semi_supervised_learning_with_gan.git
# !python ./semi_supervised_learning_with_gan/ssgan_parsbert.py -d digikalamag -p 0.01
# !python ./semi_supervised_learning_with_gan/ecgan_parsbert.py -d persiannews -p 0.01 -w 0.5 -t 0.01 -e 100
# Out:
# Streaming output truncated to the last 5000 lines.
# 11     12  68.310811
# 12     13  69.324324
# 13     14  79.324324
# 14     15  79.864865
# 15     16  80.270270
# 16     17  82.837838
# 17     18  84.459459
# 18     19  86.216216
# 19     20  84.662162
# 20     21  81.554054
# 21     22  85.608108
# 22     23  84.932432
# 23     24  86.013514
# 24     25  86.418919
# 25     26  86.621622
# 26     27  86.418919
# 27     28  87.635135
# 28     29  87.094595
# 29     30  86.621622
# 30     31  87.364865
# 31     32  87.500000
# 32     33  87.432432
# 33     34  87.297297
# 34     35  87.027027
# 35     36  87.432432
# 36     37  87.364865
# 37     38  87.770270
# 38     39  87.432432
# 39     40  87.364865
# 40     41  87.229730
# 41     42  87.635135
# 42     43  87.567568
# 43     44  88.378378
# 44     45  88.040541
# 45     46  88.108108
# 46     47  88.175676
# 47     48  88.040541
# 48     49  88.040541
# 49     50  87.635135
# 50     51  87.770270
# 51     52  88.040541
# ...
