# %% [markdown]
# <a href="https://colab.research.google.com/github/iamardian/ssgans_results/blob/main/ec_gan%7Cpersiannews%7C0.01%7C0.1%7C0.2%7C100%7CTrue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers==4.3.2
# !rm -r ./semi_supervised_learning_with_gan ;git clone https://github.com/iamardian/semi_supervised_learning_with_gan.git
# !python ./semi_supervised_learning_with_gan/ssgan_parsbert.py -d digikalamag -p 0.01
# !python ./semi_supervised_learning_with_gan/ecgan_parsbert.py -d persiannews -p 0.01 -w 0.1 -t 0.2 -e 100 -l 1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.8 MB 5.3 MB/s
# ...
#      |████████████████████████████████| 880 kB 56.5 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 47.2 MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=d6d086794cf8a46b498d65df64f510aea9f9bff5b53da5c0fdac291fcc95caa4
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# ...
# rm: cannot remove './semi_supervised_learning_with_gan': No such file or directory
# Cloning into 'semi_supervised_learning_with_gan'...
# remote: Enumerating objects: 229, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 229 (delta 41), reused 48 (delta 22), pack-reused 161
# Receiving objects: 100% (229/229), 60.42 KiB | 2.63 MiB/s, done.
# ...
