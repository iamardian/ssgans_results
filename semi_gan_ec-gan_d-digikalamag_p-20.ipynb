# %% [markdown]
# <a href="https://colab.research.google.com/github/iamardian/ssgans_results/blob/main/semi_gan_ec-gan_d-digikalamag_p-20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers==4.3.2
# !rm -r ./semi_supervised_learning_with_gan ;git clone https://github.com/iamardian/semi_supervised_learning_with_gan.git
# !python ./semi_supervised_learning_with_gan/ssgan_parsbert.py -d digikalamag -p 0.5
# !python ./semi_supervised_learning_with_gan/ecgan_parsbert.py -d digikalamag -p 0.2
# Out:
# Streaming output truncated to the last 5000 lines.
# 42     43  32.511737
# 43     44  32.511737
# 44     45  32.511737
# 277 / 852 * 100 = 32.51173708920187
#
# ======== Epoch 46 / 100 ========
# Training...
# ./semi_supervised_learning_with_gan/ecgan_parsbert.py:348: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = self.softmax(logits)
# (10) train_accuracy : 28.125
#   Batch    10  of     44.    Elapsed: 0:00:13.
# (20) train_accuracy : 28.125
#   Batch    20  of     44.    Elapsed: 0:00:27.
# (30) train_accuracy : 28.125
#   Batch    30  of     44.    Elapsed: 0:00:40.
# (40) train_accuracy : 25.78125
#   Batch    40  of     44.    Elapsed: 0:00:54.
# Epoch 46 Complete
#     epoch        acc
# 0       1  86.737089
# 1       2  88.615023
# 2       3  87.793427
# 3       4  87.793427
# 4       5  85.446009
# 5       6  71.361502
# 6       7  71.126761
# 7       8  83.685446
# 8       9  46.713615
# ...
