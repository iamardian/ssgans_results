# %% [markdown]
# <a href="https://colab.research.google.com/github/iamardian/ssgans_results/blob/main/semi_gan_ec-gan_d-persiannews_p-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers==4.3.2
# !rm -r ./semi_supervised_learning_with_gan ;git clone https://github.com/iamardian/semi_supervised_learning_with_gan.git
# !python ./semi_supervised_learning_with_gan/ssgan_parsbert.py -d persiannews -p 0.02
# !python ./semi_supervised_learning_with_gan/ecgan_parsbert.py -d persiannews -p 0.01
# Out:
# Streaming output truncated to the last 5000 lines.
# 34     35  89.659367
# 35     36  89.659367
# 1474 / 1644 * 100 = 89.65936739659367
#
# ======== Epoch 37 / 100 ========
# Training...
# ./semi_supervised_learning_with_gan/ecgan_parsbert.py:348: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = self.softmax(logits)
# Epoch 37 Complete
#     epoch        acc
# 0       1  20.255474
# 1       2  15.571776
# 2       3  15.571776
# 3       4  19.525547
# 4       5  25.425791
# 5       6  40.510949
# 6       7  41.727494
# 7       8  48.418491
# 8       9  57.420925
# 9      10  62.652068
# 10     11  70.559611
# 11     12  79.257908
# 12     13  80.231144
# 13     14  81.021898
# 14     15  80.413625
# 15     16  87.712895
# 16     17  87.895377
# 17     18  85.705596
# 18     19  88.260341
# 19     20  84.002433
# 20     21  88.929440
# 21     22  87.347932
# 22     23  89.781022
# ...
