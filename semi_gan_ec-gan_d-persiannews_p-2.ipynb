# %% [markdown]
# <a href="https://colab.research.google.com/github/iamardian/ssgans_results/blob/main/semi_gan_ec-gan_d-persiannews_p-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers==4.3.2
# !rm -r ./semi_supervised_learning_with_gan ;git clone https://github.com/iamardian/semi_supervised_learning_with_gan.git
# !python ./semi_supervised_learning_with_gan/ssgan_parsbert.py
# !python ./semi_supervised_learning_with_gan/ecgan_parsbert.py -d persiannews -p 0.02
# Out:
# Streaming output truncated to the last 5000 lines.
# 34     35  93.065693
# 35     36  92.883212
# 1527 / 1644 * 100 = 92.88321167883211
#
# ======== Epoch 37 / 100 ========
# Training...
# ./semi_supervised_learning_with_gan/ecgan_parsbert.py:348: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = self.softmax(logits)
# Epoch 37 Complete
#     epoch        acc
# 0       1  20.620438
# 1       2  15.571776
# 2       3  26.642336
# 3       4  37.347932
# 4       5  51.763990
# 5       6  69.403893
# 6       7  72.080292
# 7       8  78.467153
# 8       9  81.326034
# 9      10  83.941606
# 10     11  92.092457
# 11     12  92.639903
# 12     13  92.639903
# 13     14  92.700730
# 14     15  92.396594
# 15     16  92.639903
# 16     17  92.579075
# 17     18  92.700730
# 18     19  92.761557
# 19     20  92.700730
# 20     21  92.822384
# 21     22  92.761557
# 22     23  92.822384
# ...
