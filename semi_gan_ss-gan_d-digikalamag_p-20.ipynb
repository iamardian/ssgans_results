# %% [markdown]
# <a href="https://colab.research.google.com/github/iamardian/ssgans_results/blob/main/semi_gan_ss-gan_d-digikalamag_p-20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers==4.3.2
# !rm -r ./semi_supervised_learning_with_gan ;git clone https://github.com/iamardian/semi_supervised_learning_with_gan.git
# !python ./semi_supervised_learning_with_gan/ssgan_parsbert.py -d digikalamag -p 0.2
# !python ./semi_supervised_learning_with_gan/ecgan_parsbert.py -d digikalamag -p 0.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Cloning into 'semi_supervised_learning_with_gan'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 46 (delta 23), reused 35 (delta 15), pack-reused 0
# Unpacking objects: 100% (46/46), done.
# Dataset : digikalamag
# Percentage : 0.2
# There are 1 GPU(s) available.
# We will use the GPU: Tesla T4
# fatal: destination path 'digikalamag' already exists and is not an empty directory.
# ./digikalamag/train.csv
# ./digikalamag/test.csv
# [0, 1, 2, 3, 4, 5, 6]
# train_examples :  6896
# labeled_data_const :  1379
# labeled_examples :  1379
# unlabeled_examples :  5517
#
# ======== Epoch 1 / 100 ========
# Training...
#   Batch    10  of    130.    Elapsed: 0:00:20.
#   Batch    20  of    130.    Elapsed: 0:00:40.
#   Batch    30  of    130.    Elapsed: 0:01:01.
# ...
